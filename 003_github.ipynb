# %% [markdown]
# ### Регаемся на github.com
# после чего создаем новый репозиторий

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Далее pycharm

# %% [markdown]
# ### Создадим новый файл
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Переходим в консоль

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# git init
# git branch -M master
# ### Следующая строчка у Вас будет другая
# git remote add origin https://github.com/isupo/Django.git
# git add .
# git commit -m "init"
# git push -u origin master

# %% [markdown]
# # строчку брать отсюда
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# В итоге получим вот такую страницу на github
# ![image.png](attachment:image.png)
