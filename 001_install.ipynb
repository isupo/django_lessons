# %% [markdown]
# ### Очень быстрый старт

# %% [markdown]
# #### Лучше всего установить anaconda на свой компьютер
# При установке нужно аккуратно поставить галочку, что нужно использовать интерпритатор по умолчанию
# https://www.anaconda.com/

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Установить pycharm community
# https://www.jetbrains.com/pycharm/download/#section=windows

# %% [markdown]
# #### Создать новый проект в pycharm
# ![image.png](attachment:image.png)

# %% [markdown]
# Изменений делать не нужно, только название
# ![image.png](attachment:image.png)

# %% [markdown]
# Установить django
# ![image.png](attachment:image.png)

# %% [markdown]
# Должно подсветиться зеленым
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Установить git
# https://git-scm.com/download/win
